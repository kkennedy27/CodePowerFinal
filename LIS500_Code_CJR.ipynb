# %%
import pandas as pd

# %%
pd.options.display.max_rows = 100

# %%
moma_df = pd.read_csv('/users/camir/Downloads/Artworks.csv', delimiter=",")

# %%
moma_df
# Out:
#                                                     Title  \
# 0       Ferdinandsbrücke Project, Vienna, Austria, Ele...
# 1       City of Music, National Superior Conservatory ...
# 2       Villa near Vienna Project, Outside Vienna, Aus...
# 3       The Manhattan Transcripts Project, New York, N...
# 4       Villa, project, outside Vienna, Austria, Exter...
# ...                                                   ...
# 132398  An Episode in the Life of a Landscape Painter ...
# 132399              Incense Sweaters & Ice (Installation)
# 132400                                       Just For You
# 132401                 Marey and Demeny Chronophotographs
# 132402                          Four Saints in Three Acts
#
#                           Artist ConstituentID  \
# 0                    Otto Wagner          6210
# 1       Christian de Portzamparc          7470
# 2                     Emil Hoppe          7605
# 3                Bernard Tschumi          7056
# ...

# %%
moma_df.sample(10)
# Out:
#                                                     Title  \
# 123585                                             Beggar
# 88019                                 Nebraska Sod Houses
# 13717   Plate (folio 64) from EL INGENIOSO HIDALGO DON...
# 24968   A bad night (Mala noche) (plate 36, folio 36) ...
# 19020               Anatol' Petryts'kyi. Teatral'ni stroi
# 111537                                   Bad Luck Blackie
# 120422                                Le Mirliton, no. 92
# 22586   Tailpiece (page 422) from L'IMITATION DE JÉSUS...
# 108613                             Lustrasilk from DeLuxe
# 61754                                A. J. M. IN MEMORIAM
#
#                               Artist ConstituentID               ArtistBio  \
# 123585                    Uche Okeke         47956   (Nigerian, 1933–2016)
# 88019             Solomon D. Butcher           895   (American, 1856–1927)
# 13717                  Roberto Matta          3842    (Chilean, 1911–2002)
# ...

# %%
moma_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132403 entries, 0 to 132402
# Data columns (total 29 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Title               132349 non-null  object
#  1   Artist              130942 non-null  object
#  2   ConstituentID       130942 non-null  object
#  3   ArtistBio           127669 non-null  object
#  4   Nationality         130942 non-null  object
#  5   BeginDate           130942 non-null  object
#  6   EndDate             130942 non-null  object
#  7   Gender              130942 non-null  object
#  8   Date                130237 non-null  object
#  9   Medium              121178 non-null  object
#  10  Dimensions          121160 non-null  object
#  11  CreditLine          129479 non-null  object
#  12  AccessionNumber     132403 non-null  object
#  13  Classification      132403 non-null  object
#  14  Department          132403 non-null  object
# ...

# %%
moma_df.describe()
# Out:
#             ObjectID  Circumference (cm)    Depth (cm)  Diameter (cm)  \
# count  132403.000000           10.000000  11924.000000    1418.000000
# mean    84908.621942           44.868020     17.896096      23.160581
# std     60779.114413           28.631604     57.489020      45.229341
# min         2.000000            9.900000      0.000000       0.635000
# 25%     34774.500000           23.500000      0.000000       7.800000
# 50%     70762.000000           36.000000      0.500000      13.652500
# 75%    132257.500000           71.125000     12.100000      24.765000
# max    274904.000000           83.800000   1808.483617     914.400000
#
#          Height (cm)  Length (cm)    Weight (kg)     Width (cm)  \
# count  113638.000000   738.000000     293.000000  112739.000000
# mean       37.772076    90.009375    1269.697877      38.253816
# std        48.067565   330.313873   11956.391641      67.232190
# min         0.000000     0.000000       0.090000       0.000000
# ...

# %%
moma_df.describe(include='all')
# Out:
#            Title        Artist ConstituentID            ArtistBio Nationality  \
# count     132349        130942        130942               127669      130942
# unique     96118         13862         13908                 7952         995
# top     Untitled  Eugène Atget           229  (French, 1857–1927)  (American)
# freq        7360          5050          5050                 5050       55486
# mean         NaN           NaN           NaN                  NaN         NaN
# std          NaN           NaN           NaN                  NaN         NaN
# min          NaN           NaN           NaN                  NaN         NaN
# 25%          NaN           NaN           NaN                  NaN         NaN
# 50%          NaN           NaN           NaN                  NaN         NaN
# 75%          NaN           NaN           NaN                  NaN         NaN
# max          NaN           NaN           NaN                  NaN         NaN
#
# ...

# %%
moma_df['Nationality']
# Out:
# 0         (Austrian)
# 1           (French)
# 2         (Austrian)
# 3                 ()
# 4         (Austrian)
#              ...
# 132398           NaN
# 132399    (American)
# 132400    (American)
# 132401           NaN
# 132402    (American)
# Name: Nationality, Length: 132403, dtype: object

# %%
moma_df['Artist']
# Out:
# 0                      Otto Wagner
# 1         Christian de Portzamparc
# 2                       Emil Hoppe
# 3                  Bernard Tschumi
# 4                       Emil Hoppe
#                     ...
# 132398                         NaN
# 132399                Martine Syms
# 132400                Ken Friedman
# 132401                         NaN
# 132402                 Julien Levy
# Name: Artist, Length: 132403, dtype: object

# %%
moma_df[['Artist']]
# Out:
#                           Artist
# 0                    Otto Wagner
# 1       Christian de Portzamparc
# 2                     Emil Hoppe
# 3                Bernard Tschumi
# 4                     Emil Hoppe
# ...                          ...
# 132398                       NaN
# 132399              Martine Syms
# 132400              Ken Friedman
# 132401                       NaN
# 132402               Julien Levy
#
# [132403 rows x 1 columns]

# %%
moma_df[['Artist','Date','Medium']]
# Out:
#                           Artist       Date  \
# 0                    Otto Wagner       1896
# 1       Christian de Portzamparc       1987
# 2                     Emil Hoppe       1903
# 3                Bernard Tschumi       1980
# 4                     Emil Hoppe       1903
# ...                          ...        ...
# 132398                       NaN       2006
# 132399              Martine Syms       2017
# 132400              Ken Friedman       1967
# 132401                       NaN  1892–1900
# 132402               Julien Levy       1934
#
#                                                    Medium
# 0           Ink and cut-and-pasted painted pages on paper
# 1                       Paint and colored pencil on print
# 2       Graphite, pen, color pencil, ink, and gouache ...
# 3       Photographic reproduction with colored synthet...
# 4       Graphite, color pencil, ink, and gouache on tr...
# ...                                                   ...
# ...

# %%
moma_df['Nationality'].value_counts()
# Out:
# Nationality
# (American)                                                                55486
# (French)                                                                  22460
# (German)                                                                   9125
# (British)                                                                  5542
# ()                                                                         3314
#                                                                           ...
# (Various) (British) (American) (British) (British)                            1
# (Various) (British) (German) (American)                                       1
# (Russian) (Russian) () ()                                                     1
# (Various) (Russian) (Russian) () () () (Russian) () () (Russian) () ()        1
# (Finnish) ()                                                                  1
# Name: count, Length: 995, dtype: int64

# %%
moma_df['Medium'].value_counts()[:10]
# Out:
# Medium
# Gelatin silver print            14676
# Lithograph                       7083
# Albumen silver print             4847
# Lithograph, printed in color     1761
# Pencil on paper                  1741
# Etching                          1608
# Chromogenic color print          1524
# Letterpress                      1450
# Ink on paper                     1412
# Lithograph, printed in black     1389
# Name: count, dtype: int64

# %%
moma_df['Nationality'].value_counts()[:10]
# Out:
# Nationality
# (American)    55486
# (French)      22460
# (German)       9125
# (British)      5542
# ()             3314
# (Spanish)      3077
# (Italian)      2745
# (Japanese)     2363
# (Swiss)        1974
# (Russian)      1530
# Name: count, dtype: int64

# %%
moma_df['Medium'].value_counts()[:10].plot(kind='bar', title='MoMA Artworks Most Frequent Mediums')
# Out:
# <Axes: title={'center': 'MoMA Artworks Most Frequent Mediums'}, xlabel='Medium'>

# %%
moma_df['Nationality'].value_counts()[:10].plot(kind='pie', figsize=(10,10), title='Artist Nationalities')
# Out:
# <Axes: title={'center': 'Artist Nationalities'}, ylabel='count'>

# %%
ax=moma_df['Nationality'].value_counts()[:10].plot(kind='pie', figsize=(10,10), title='Artist Nationalities')
ax.figure.savefig('moma-artist-nationalities_piechart.pdf')

# %%
moma_df
# Out:
#                                                     Title  \
# 0       Ferdinandsbrücke Project, Vienna, Austria, Ele...
# 1       City of Music, National Superior Conservatory ...
# 2       Villa near Vienna Project, Outside Vienna, Aus...
# 3       The Manhattan Transcripts Project, New York, N...
# 4       Villa, project, outside Vienna, Austria, Exter...
# ...                                                   ...
# 132398  An Episode in the Life of a Landscape Painter ...
# 132399              Incense Sweaters & Ice (Installation)
# 132400                                       Just For You
# 132401                 Marey and Demeny Chronophotographs
# 132402                          Four Saints in Three Acts
#
#                           Artist ConstituentID  \
# 0                    Otto Wagner          6210
# 1       Christian de Portzamparc          7470
# 2                     Emil Hoppe          7605
# 3                Bernard Tschumi          7056
# ...

# %%
moma_df.columns
# Out:
# Index(['Title', 'Artist', 'ConstituentID', 'ArtistBio', 'Nationality',
#        'BeginDate', 'EndDate', 'Gender', 'Date', 'Medium', 'Dimensions',
#        'CreditLine', 'AccessionNumber', 'Classification', 'Department',
#        'DateAcquired', 'Cataloged', 'ObjectID', 'URL', 'ThumbnailURL',
#        'Circumference (cm)', 'Depth (cm)', 'Diameter (cm)', 'Height (cm)',
#        'Length (cm)', 'Weight (kg)', 'Width (cm)', 'Seat Height (cm)',
#        'Duration (sec.)'],
#       dtype='object')

# %%
moma_df['URL'].notna()
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 132398    False
# 132399    False
# 132400    False
# 132401    False
# 132402    False
# Name: URL, Length: 132403, dtype: bool

# %%
moma_df[moma_df['URL'].notna()]
# Out:
#                                                     Title  \
# 0       Ferdinandsbrücke Project, Vienna, Austria, Ele...
# 1       City of Music, National Superior Conservatory ...
# 2       Villa near Vienna Project, Outside Vienna, Aus...
# 3       The Manhattan Transcripts Project, New York, N...
# 4       Villa, project, outside Vienna, Austria, Exter...
# ...                                                   ...
# 132263      8th Poster (Ibiza) (for Parkett, no. 100/101)
# 132273                                          Landslide
# 132331                                           Untitled
# 132332                                           Untitled
# 132395  Pavilion Apartments, Newark, New Jersey (Plan ...
#
#                                Artist ConstituentID  \
# 0                         Otto Wagner          6210
# 1            Christian de Portzamparc          7470
# 2                          Emil Hoppe          7605
# 3                     Bernard Tschumi          7056
# ...
